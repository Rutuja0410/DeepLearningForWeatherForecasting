# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df = df[5::6]    #getting every hour data
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
# df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')

df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33     -9.17    264.12
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17     -8.10    265.12
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69     -7.66    265.52
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27     -7.04    266.10
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87     -7.41    265.68
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# ...

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <AxesSubplot:xlabel='Date Time'>

# %%
# Using last 5 hours temp to predict temp for current hour
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy()
    x = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = [[a] for a in df_as_np[i:i+window_size]]
        x.append(row)
        label = df_as_np[i+window_size]
        y.append(label)
    return np.array(x), np.array(y)

WINDOW_SIZE = 5
x, y = df_to_X_y(temp, WINDOW_SIZE)
print("x shape: ",x.shape, "y shape: ", y.shape)
# Out:
# x shape:  (70086, 5, 1) y shape:  (70086,)

# %%
x_train, y_train = x[:60000], y[:60000]
x_val, y_val = x[60000:65000], y[60000:65000]
x_test, y_test = x[65000:], y[65000:]
x_train.shape, x_val.shape, x_test.shape
# Out:
# ((60000, 5, 1), (5000, 5, 1), (5086, 5, 1))

# %% [markdown]
# ## LSTM Model

# %% [markdown]
# ### Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5,1)))
model1.add(LSTM(64))
model1.add(Dense(8,'relu'))
model1.add(Dense(1,'linear'))


model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# ...
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001),metrics=[RootMeanSquaredError()])

# %% [markdown]
# ### Model training

# %%
model1.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 20s 8ms/step - loss: 30.3061 - root_mean_squared_error: 5.5051 - val_loss: 1.0619 - val_root_mean_squared_error: 1.0305
# Epoch 2/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 1.7687 - root_mean_squared_error: 1.3299 - val_loss: 0.5874 - val_root_mean_squared_error: 0.7664
# Epoch 3/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.8641 - root_mean_squared_error: 0.9296 - val_loss: 0.5191 - val_root_mean_squared_error: 0.7205
# Epoch 4/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.7155 - root_mean_squared_error: 0.8459 - val_loss: 0.5253 - val_root_mean_squared_error: 0.7248
# Epoch 5/10
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.6797 - root_mean_squared_error: 0.8244 - val_loss: 0.5021 - val_root_mean_squared_error: 0.7086
# Epoch 6/10
# ...

# %% [markdown]
# ### Model Prediction

# %%
# Prediction on Validation data
val_predictions = model1.predict(x_val).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val})
val_results
# Out:
# 157/157 [==============================] - 1s 4ms/step
#       Val Predictions  Actuals
# 0           15.509393    14.02
# 1           13.381633    13.67
# 2           13.101390    12.27
# 3           11.488985    11.19
# 4           10.405812    10.85
# ...               ...      ...
# 4995        17.414797    18.27
# 4996        17.358959    17.85
# 4997        17.244471    16.65
# 4998        15.957397    15.85
# 4999        15.181502    15.09
#
# [5000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %%
# Prediction on Test data
test_predictions = model1.predict(x_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test})
test_results
# Out:
# 159/159 [==============================] - 1s 4ms/step
#       Test Predictions  Actuals
# 0            14.487042    13.99
# 1            13.280863    13.46
# 2            12.898703    12.93
# 3            12.488484    12.43
# 4            12.037678    12.17
# ...                ...      ...
# 5081         -1.049615    -0.98
# 5082         -1.306387    -1.40
# 5083         -1.651053    -2.75
# 5084         -3.196091    -2.89
# 5085         -3.109896    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])

# %% [markdown]
# ### Model evaluation

# %%
from sklearn.metrics import mean_squared_error as mse

def plot_predictions1(model, X, y, start=0, end=100):
    predictions = model.predict(X).flatten()
    df = pd.DataFrame(data={'Predictions': predictions, 'Actuals':y, 'Difference':(predictions-y)})
    plt.figure(figsize=(12, 6))
    plt.plot(df['Actuals'][start:end], label="True Values", color="blue")
    plt.plot(df['Predictions'][start:end], label="Predicted Values", color="orange", linestyle="--")
    plt.title("True vs Predicted Values")
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.legend()
    plt.grid()
    plt.show()
    return df, mse(predictions, y)

# %%
res, mserror = plot_predictions1(model1, x_test, y_test)
print('MSE :',mserror)
# Out:
# 159/159 [==============================] - 1s 5ms/step
# MSE : 0.6204689805920369

# %% [markdown]
# #### From the graph, we can infer that the difference between the actual and predicted values are relatively small, indicating that the model's predictions closely align with the true values.

# %%
res.head(5)
# Out:
#    Predictions  Actuals  Difference
# 0    14.487042    13.99    0.497042
# 1    13.280863    13.46   -0.179137
# 2    12.898703    12.93   -0.031297
# 3    12.488484    12.43    0.058484
# 4    12.037678    12.17   -0.132322

# %%
plt.figure(figsize=(10, 6))
plt.plot(df.index[0:300], res["Difference"][0:300], label="Residuals", color="red")
plt.axhline(0, linestyle="--", color="gray")
plt.title("Residuals (Error Over Time)")
plt.xlabel("Time Steps")
plt.ylabel("Error")
plt.legend()
plt.show()

# %% [markdown]
# #### The residuals consistently fall above or below zero. Therefore, we can conclude that the model is unbiased
